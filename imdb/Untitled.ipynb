# %%
import pandas as pd

# %%
df = pd.concat(
    map(pd.read_csv, ['train-1.csv', 'train-2.csv', 'train-3.csv', 'train-4.csv', 'train-5.csv', 'train-6.csv', 'train-7.csv']), ignore_index=True)
print(df)
# Out:
#       Unnamed: 0     tconst                               primaryTitle  \
# 0              4  tt0010600                                   The Doll
# 1              7  tt0011841                              Way Down East
# 2              9  tt0012494                                    Déstiny
# 3             25  tt0015163                              The Navigator
# 4             38  tt0016220                   The Phantom of the Opera
# ...          ...        ...                                        ...
# 6961        9957  tt9580138  Mortal Kombat Legends: Scorpion's Revenge
# 6962        9958  tt9586294                                Better Days
# 6963        9969  tt9652782                                       Bait
# 6964        9983  tt9766294                              Fauji Calling
# 6965        9986  tt9784798                Judas and the Black Messiah
#
#                                   originalTitle startYear endYear  \
# ...

# %%
df
# Out:
#       Unnamed: 0     tconst                               primaryTitle  \
# 0              4  tt0010600                                   The Doll
# 1              7  tt0011841                              Way Down East
# 2              9  tt0012494                                    Déstiny
# 3             25  tt0015163                              The Navigator
# 4             38  tt0016220                   The Phantom of the Opera
# ...          ...        ...                                        ...
# 6961        9957  tt9580138  Mortal Kombat Legends: Scorpion's Revenge
# 6962        9958  tt9586294                                Better Days
# 6963        9969  tt9652782                                       Bait
# 6964        9983  tt9766294                              Fauji Calling
# 6965        9986  tt9784798                Judas and the Black Messiah
#
#                                   originalTitle startYear endYear  \
# ...

# %%
writing=pd.read_json(r'writing.json')
directing=pd.read_json(r'directing.json')

# %%
df_both = pd.merge(writing, directing,
                        how="left", on=["movie"])

# %%
df['startYear'] = df['startYear'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_283787/1063799019.py in <module>
# ----> 1 df['startYear'] = df['startYear'].astype(int)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df['startYear'] = df['startYear'].replace('\\N', "")

# %%
df['startYear'] = df['startYear'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_283787/1063799019.py in <module>
# ----> 1 df['startYear'] = df['startYear'].astype(int)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
writing
# Out:
#            movie     writer
# 0      tt0003740  nm0195339
# 1      tt0003740  nm0515385
# 2      tt0003740  nm0665163
# 3      tt0003740  nm0758215
# 4      tt0008663  nm0406585
# ...          ...        ...
# 22423  tt9904802  nm0942647
# 22424  tt9904802  nm3853396
# 22425  tt9911196  nm2063122
# 22426  tt9911196  nm0277932
# 22427  tt9911196  nm3547655
#
# [22428 rows x 2 columns]

# %%
df_both
# Out:
#            movie     writer   director
# 0      tt0003740  nm0195339  nm0665163
# 1      tt0003740  nm0515385  nm0665163
# 2      tt0003740  nm0665163  nm0665163
# 3      tt0003740  nm0758215  nm0665163
# 4      tt0008663  nm0406585  nm0803705
# ...          ...        ...        ...
# 27883  tt9904802  nm0942647  nm0052054
# 27884  tt9904802  nm3853396  nm0052054
# 27885  tt9911196  nm2063122  nm0631590
# 27886  tt9911196  nm0277932  nm0631590
# 27887  tt9911196  nm3547655  nm0631590
#
# [27888 rows x 3 columns]

# %%
df_both = pd.merge(df, df_both,
                        how="left", on=["movie"])
